# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayoub-kharrat/Projet-Colourizing-Old-B-W-Images/blob/main/Kharrat_Ayoub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **<font color='blue'> Artistic Colorizer </font>**

# %%
# !git clone https://github.com/jantic/DeOldify.git DeOldify
# Out:
# fatal: destination path 'DeOldify' already exists and is not an empty directory.

# %%
cd DeOldify
# Out:
# /content/DeOldify

# %%
#NOTE:  This must be the first call in order to work properly!
from deoldify import device
from deoldify.device_id import DeviceId
#choices:  CPU, GPU0...GPU7
device.set(device=DeviceId.GPU0)

import torch

if not torch.cuda.is_available():
    print('GPU not available.')

# %%
# !pip install -r requirements-colab.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import fastai
from deoldify.visualize import *
import warnings
warnings.filterwarnings("ignore", category=UserWarning, message=".*?Your .*? set is empty.*?")
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# NumExpr defaulting to 2 threads.

# %%
# !mkdir 'models'
# !wget https://data.deepai.org/deoldify/ColorizeArtistic_gen.pth -O ./models/ColorizeArtistic_gen.pth
# Out:
# mkdir: cannot create directory ‘models’: File exists
# --2023-05-14 13:01:11--  https://data.deepai.org/deoldify/ColorizeArtistic_gen.pth
# Resolving data.deepai.org (data.deepai.org)... 138.199.37.231, 2400:52e0:1e00::1075:1
# Connecting to data.deepai.org (data.deepai.org)|138.199.37.231|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 255144681 (243M) [application/octet-stream]
# Saving to: ‘./models/ColorizeArtistic_gen.pth’
#
# ./models/ColorizeAr 100%[===================>] 243.32M  4.83MB/s    in 50s
#
# 2023-05-14 13:02:02 (4.84 MB/s) - ‘./models/ColorizeArtistic_gen.pth’ saved [255144681/255144681]

# %%
colorizer = get_image_colorizer(artistic=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
source_url = 'd' #@param {type:"string"}
render_factor = 32  #@param {type: "slider", min: 7, max: 40}
watermarked = True #@param {type:"boolean"}

if source_url is not None and source_url !='':
    image_path = colorizer.plot_transformed_image(path='/content/DeOldify/278767087_3085322308401570_8575016033454594444_n.jpg', render_factor=render_factor, compare=True)
    show_image_in_notebook(image_path)
else:
    print('Provide an image url and try again.')

# %% [markdown]
# ---
# #⚙ Recommended image sources
# * [/r/TheWayWeWere](https://www.reddit.com/r/TheWayWeWere/)
